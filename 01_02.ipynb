# %%
import pandas as pd

df = pd.read_csv('diverse_dataset.csv')
print(df)
# Out:
#         Name   Age          City
# 0      Alice  24.0         Paris
# 1        Bob   NaN   Los Angeles
# 2    Charlie  22.0           NaN
# 3      David  29.0         Dubai
# 4    Saoirse   NaN        Dublin
# 5  Fatimatou  27.0         Dakar
# 6       Fang  30.0       Beijing
# 7     Hassan   NaN         Cairo
# 8     Ingrid  25.0           NaN
# 9   Blessing  26.0  Johannesburg

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    10 non-null     object
#  1   Age     7 non-null      float64
#  2   City    8 non-null      object
# dtypes: float64(1), object(2)
# memory usage: 368.0+ bytes

# %%
valeurs_manquantes = df.isnull()
print (valeurs_manquantes)
# Out:
#     Name    Age   City
# 0  False  False  False
# 1  False   True  False
# 2  False  False   True
# 3  False  False  False
# 4  False   True  False
# 5  False  False  False
# 6  False  False  False
# 7  False   True  False
# 8  False  False   True
# 9  False  False  False

# %%
valeurs_manquantes = df.isnull().sum()
print (valeurs_manquantes)
# Out:
# Name    0
# Age     3
# City    2
# dtype: int64

# %%
valeurs_manquantes = df.notnull().sum()
print (valeurs_manquantes)
# Out:
# Name    10
# Age      7
# City     8
# dtype: int64

# %%
lignes_manquantes = df.isna().any(axis=1)
print(df[lignes_manquantes])
# Out:
#       Name   Age         City
# 1      Bob   NaN  Los Angeles
# 2  Charlie  22.0          NaN
# 4  Saoirse   NaN       Dublin
# 7   Hassan   NaN        Cairo
# 8   Ingrid  25.0          NaN

# %%
pip install missingno
# Out:
# Collecting missingno
#   Downloading missingno-0.5.2-py3-none-any.whl (8.7 kB)
# Requirement already satisfied: numpy in c:\users\inpt\anaconda3\lib\site-packages (from missingno) (1.26.4)
# Requirement already satisfied: matplotlib in c:\users\inpt\anaconda3\lib\site-packages (from missingno) (3.7.0)
# Requirement already satisfied: seaborn in c:\users\inpt\anaconda3\lib\site-packages (from missingno) (0.12.2)
# Requirement already satisfied: scipy in c:\users\inpt\anaconda3\lib\site-packages (from missingno) (1.10.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\inpt\anaconda3\lib\site-packages (from matplotlib->missingno) (2.8.2)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\inpt\anaconda3\lib\site-packages (from matplotlib->missingno) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\inpt\anaconda3\lib\site-packages (from matplotlib->missingno) (1.4.4)
# Requirement already satisfied: cycler>=0.10 in c:\users\inpt\anaconda3\lib\site-packages (from matplotlib->missingno) (0.11.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\inpt\anaconda3\lib\site-packages (from matplotlib->missingno) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\inpt\anaconda3\lib\site-packages (from matplotlib->missingno) (3.0.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\inpt\anaconda3\lib\site-packages (from matplotlib->missingno) (23.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\inpt\anaconda3\lib\site-packages (from matplotlib->missingno) (1.0.5)
# Requirement already satisfied: pandas>=0.25 in c:\users\inpt\anaconda3\lib\site-packages (from seaborn->missingno) (1.5.3)
# Requirement already satisfied: pytz>=2020.1 in c:\users\inpt\anaconda3\lib\site-packages (from pandas>=0.25->seaborn->missingno) (2022.7)
# Requirement already satisfied: six>=1.5 in c:\users\inpt\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->missingno) (1.16.0)
# Installing collected packages: missingno
# Successfully installed missingno-0.5.2
# Note: you may need to restart the kernel to use updated packages.

# %%
import missingno as msno
msno.matrix(df)
# Out:
# <Axes: >
